# %%
import pandas as pd

# %%
df = pd.read_pickle("industry_project_df.pkl")
df.head()
# Out:
#    id                                 title                 category  \
# 0   1     Account Opening Process (NRE/NRO)  Process & Documentation
# 1   2          AML & Transaction Monitoring  Compliance & Regulatory
# 2   3  Premium Credit Card – Elite Platinum      Product Information
# 3   4             FATCA and CRS Declaration  Compliance & Regulatory
# 4   5    FEMA Guidelines – NRE/NRO Accounts  Compliance & Regulatory
#
#                                              content
# 0  The account opening process involves four step...
# 1  Banks must monitor transactions for suspicious...
# 2  The Elite Platinum card is designed for high-n...
# 3  All NRI customers must declare tax residency u...
# 4  FEMA guidelines stipulate that NRE account bal...
